# %%
#importing the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#import all the required library for machine learning
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report,confusion_matrix


from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

import warnings
warnings.filterwarnings("ignore")

# %%
creditcard_data = pd.read_csv("/content/creditcard.csv")

# %%
creditcard_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
creditcard_data.shape
creditcard_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241653 entries, 0 to 241652
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    241653 non-null  float64
#  1   V1      241653 non-null  float64
#  2   V2      241653 non-null  float64
#  3   V3      241653 non-null  float64
#  4   V4      241653 non-null  float64
#  5   V5      241653 non-null  float64
#  6   V6      241653 non-null  float64
#  7   V7      241653 non-null  float64
#  8   V8      241653 non-null  float64
#  9   V9      241653 non-null  float64
#  10  V10     241653 non-null  float64
#  11  V11     241653 non-null  float64
#  12  V12     241653 non-null  float64
#  13  V13     241653 non-null  float64
#  14  V14     241653 non-null  float64
#  15  V15     241653 non-null  float64
#  16  V16     241653 non-null  float64
#  17  V17     241653 non-null  float64
#  18  V18     241652 non-null  float64
#  19  V19     241652 non-null  float64
#  20  V20     241652 non-null  float64
#  21  V21     241652 non-null  float64
#  22  V22     241651 non-null  float64
#  23  V23     241651 non-null  float64
#  24  V24     241651 non-null  float64
#  25  V25     241651 non-null  float64
#  26  V26     241651 non-null  float64
#  27  V27     241651 non-null  float64
#  28  V28     241651 non-null  float64
#  29  Amount  241651 non-null  float64
#  30  Class   241651 non-null  float64
# dtypes: float64(31)
# memory usage: 57.2 MB

# %%
creditcard_data.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  241653.000000  241653.000000  241653.000000  241653.000000
# mean    82439.010205      -0.055844      -0.016081       0.140259
# std     41122.539919       1.957926       1.671933       1.500597
# min         0.000000     -56.407510     -72.715728     -33.680984
# 25%     49314.000000      -0.944820      -0.603970      -0.646688
# 50%     75974.000000      -0.023340       0.066097       0.328696
# 75%    123989.000000       1.253635       0.783677       1.127508
# max    150214.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  241653.000000  241653.000000  241653.000000  241653.000000
# mean        0.036177      -0.049592       0.024699      -0.020026
# std         1.413194       1.376269       1.325113       1.229431
# min        -5.683171     -42.147898     -26.160506     -43.557242
# 25%        -0.828780      -0.736184      -0.740045      -0.565477
# 50%         0.029366      -0.107568      -0.244271       0.015852
# 75%         0.816400       0.550440       0.427446       0.540968
# max        16.875344      34.801666      22.529298      36.877368
#
#                   V8             V9  ...            V21            V22  \
# count  241653.000000  241653.000000  ...  241652.000000  241651.000000
# mean        0.002777       0.000557  ...      -0.004314      -0.017496
# std         1.207388       1.116466  ...       0.743164       0.712675
# min       -73.216718     -13.434066  ...     -34.830382     -10.933144
# 25%        -0.198452      -0.658234  ...      -0.225497      -0.534210
# 50%         0.031379      -0.063699  ...      -0.033073      -0.007663
# 75%         0.332018       0.608073  ...       0.172721       0.483903
# max        20.007208      15.594995  ...      27.202839      10.503090
#
#                  V23            V24            V25            V26  \
# count  241651.000000  241651.000000  241651.000000  241651.000000
# mean       -0.008175       0.000895       0.029478       0.002450
# std         0.641527       0.606449       0.512340       0.486309
# min       -44.807735      -2.836627     -10.295397      -2.604551
# 25%        -0.166094      -0.349664      -0.282634      -0.330566
# 50%        -0.020572       0.046407       0.063623      -0.058746
# 75%         0.131263       0.429739       0.369145       0.250310
# max        22.528412       4.022866       7.519589       3.517346
#
#                  V27            V28         Amount          Class
# count  241651.000000  241651.000000  241651.000000  241651.000000
# mean       -0.000493       0.001311      90.975249       0.001808
# std         0.402369       0.333185     251.947971       0.042487
# min       -22.565679     -11.710896       0.000000       0.000000
# 25%        -0.070287      -0.049323       6.000000       0.000000
# 50%         0.002861       0.014952      23.330000       0.000000
# 75%         0.089305       0.078078      79.965000       0.000000
# max        12.152401      33.847808   19656.530000       1.000000
#
# [8 rows x 31 columns]

# %%
creditcard_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       1
# V19       1
# V20       1
# V21       1
# V22       2
# V23       2
# V24       2
# V25       2
# V26       2
# V27       2
# V28       2
# Amount    2
# Class     2
# dtype: int64

# %%
creditcard_data.Class.value_counts()
# Out:
# Class
# 0.0    241214
# 1.0       437
# Name: count, dtype: int64

# %%
ax = creditcard_data.Class.value_counts().plot(kind='bar')

plt.title("Transaction Class Distribution")
plt.xlabel("Class")
plt.ylabel("Frequncy")
# Out:
# Text(0, 0.5, 'Frequncy')

# %%
normal = creditcard_data[creditcard_data.Class == 0]
fraud = creditcard_data[creditcard_data.Class == 1]
print(normal.shape)
print(fraud.shape)
nt = len(normal)/len(creditcard_data)*100
print(nt)
ft = len(fraud)/len(creditcard_data)*100
print(ft)
# Out:
# (241214, 31)
# (437, 31)
# 99.81833455409202
# 0.1808378128970052

# %%
normal.Amount.describe()
# Out:
# count    241214.000000
# mean         90.916455
# std         251.938305
# min           0.000000
# 25%           6.000000
# 50%          23.360000
# 75%          79.950000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     437.000000
# mean      123.428146
# std       255.460842
# min         0.000000
# 25%         1.000000
# 50%        11.000000
# 75%       105.990000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Amount per transaction by class')
bins = 50
ax1.hist(fraud.Amount, bins = bins)
ax1.set_title('Fraud')
ax2.hist(normal.Amount, bins = bins)
ax2.set_title('Normal')
plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')
plt.xlim((0, 20000))
plt.yscale('log')
plt.show();

# %%
plt.figure(figsize=(20,20))
sns.heatmap(creditcard_data.corr(),cmap="RdYlGn", annot=True)
# Out:
# <Axes: >

# %%
ligit = normal.sample(n=492)
new_df  = pd.concat([ligit,fraud], axis = 0)
new_df["Class"].value_counts()
# Out:
# Class
# 0.0    492
# 1.0    437
# Name: count, dtype: int64

# %%
x = new_df.drop(columns= "Class", axis = 1)
y = new_df.Class

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state= 40)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (743, 30) (186, 30) (743,) (186,)

# %%
creditcard_data.shape
# Out:
# (241653, 31)

# %%
model_params = {
    'logistic regression' : {
        'model': LogisticRegression(),
        'parameter' : {
            'solver': ['liblinear']
        }
    },
    'svm' : {
        'model' : svm.SVC(),
        'parameter' : {
            'kernel' : ['rbf','linear'],
            'C' : [10,15,20]
        }
    },
    'decision tree' : {
        'model' : DecisionTreeClassifier(),
        'parameter' : {
            'criterion' : ['gini', 'entropy']
        }
    },
    'random forest' : {
        'model': RandomForestClassifier(),
        'parameter' : {
            'criterion': ['gini','entropy'],
            'n_estimators' : [50,100,150]
        }
    },
    'naive_bayes_gaussian' : {
        'model' : GaussianNB(),
        'parameter' : {}
    },
    'k nearest neighbors': {
        'model' : KNeighborsClassifier(),
        'parameter' : {
            'n_neighbors' : [5,10,15]
        }
    }
}

# %%
from sklearn.model_selection import RandomizedSearchCV
import pandas as pd

score = []  # Initialize an empty list to store results

for model_name, mp in model_params.items():
    clf = RandomizedSearchCV(
        estimator=mp['model'],
        param_distributions=mp['parameter'],  # Randomized search instead of full grid
        cv=3,  # Reduce cross-validation folds from 5 to 3
        n_iter=10,  # Test only 10 random parameter combinations instead of all
        n_jobs=-1,  # Use all available CPU cores
        verbose=1,  # Display progress
        random_state=42  # Ensure reproducibility
    )

    clf.fit(x_train, y_train)

    score.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })

# Convert results into a DataFrame
cc_df = pd.DataFrame(score, columns=['model', 'best_score', 'best_params'])
print(cc_df)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
#                   model  best_score  \
# 0   logistic regression    0.932725
# 1                   svm    0.907155
# 2         decision tree    0.905800
# 3         random forest    0.947537
# 4  naive_bayes_gaussian    0.896369
# 5   k nearest neighbors    0.644699
#
#                                      best_params
# 0                        {'solver': 'liblinear'}
# 1                  {'kernel': 'linear', 'C': 15}
# 2                       {'criterion': 'entropy'}
# 3  {'n_estimators': 100, 'criterion': 'entropy'}
# 4                                             {}
# 5                            {'n_neighbors': 10}
